# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

# %%
def find(yr, cluster):
    data = pd.read_csv("leiden_cluster_table_"+str(yr)+".tsv", sep = "\t")
    #print(len(data))
    data = data[data.cl == cluster]
    data.rename(columns = {"id":"pmid"}, inplace = True)
    print(len(data))
    #print(data.dtypes)
    d2 = pd.read_csv("hicite_apt_"+str(yr)+".tsv", sep="\t")
    d = pd.DataFrame()
    d['pmid'] = d2['pmid']
    d['year'] = d2['year']
    d['human'] = d2['human']
    #print(d.dtypes)
    result = pd.merge(data,d,on='pmid',how = 'inner')
    print("length of result ",len(result))
    res = result.copy()
    '''res = result.drop(['pmid','cl'], axis = 1)
    print(res.dtypes)
    print(len(res))'''
    '''p = res[res.year == 2001]
    print("djhd ",p['human'].mean())'''
    a = res.groupby(['year'])['human'].mean().reset_index()
    #print(a.dtypes)
    a = a.sort_values(by=['year'])
    reg = linregress(x=a['year'], y=a['human'])
    print("regression ",reg.slope)
    #print(reg)
    return reg.slope
    '''dx = np.diff(a['year'])

    dy = np.diff(a['human'])

    sl = dy/dx
    
    print("dfjkdf ",sum(sl)/len(sl))
    
    #print(a)
    a = a.to_numpy()
    i = 1
    slope = []
    while(i<a.shape[0]):
        t= (a[i][1] - a[i-1][1])/(a[i][0]-a[i-1][0])
        slope.append(t)
        i += 1
    print(sum(slope)/len(slope))'''
    
    '''fig = plt.figure(figsize=(6.5,5.5))
    ax = sns.scatterplot(data = a,x='year',y='human')
    plt.show()'''
#find(2018, 1)

# %%
cls = pd.read_csv("features_prediction_2013.csv")
cls = cls[cls.n > 100]
cls = cls.sample(n=100, replace = False)
cls = cls['cluster'].unique()
cl = []
slope = []
for a in cls:
    slope.append(find(2013, a))
    cl.append(a)
    
final = pd.DataFrame()
final['cluster'] = cl
final['slope'] = slope
final['year'] = 2013
final.to_csv("slope_data_2013.csv", index = False)
# Out:
# 117
# length of result  117
# regression  0.0012819130934164768
# 1066
# length of result  1066
# regression  0.00933405389257009
# 669
# length of result  669
# regression  0.004672057345454472
# 101
# length of result  101
# regression  -0.0008217298115100137
# 7357
# length of result  7357
# regression  0.00517184204929089
# 151
# length of result  151
# regression  -0.00047983805518666075
# 318
# length of result  318
# regression  0.006670797074668689
# 1503
# length of result  1503
# regression  0.007628027719455744
# 6837
# length of result  6837
# regression  0.000549943752799863
# 2248
# length of result  2248
# regression  0.0011694232266954618
# 119
# length of result  119
# regression  0.00769203231509598
# 1243
# length of result  1243
# regression  -7.504388696733814e-05
# 126
# length of result  126
# regression  0.002979173201628266
# 7012
# length of result  7012
# regression  0.0006961323504349411
# 903
# length of result  903
# regression  0.0019300780887864216
# 144
# length of result  144
# regression  -0.006871261131032787
# 4043
# length of result  4043
# regression  0.00864884584300033
# 106
# length of result  106
# regression  -0.0013453616260541764
# 114
# length of result  114
# regression  0.009374272109221172
# 156
# length of result  156
# regression  -0.002530379005140946
# 104
# length of result  104
# regression  0.02842921042263469
# 1607
# length of result  1607
# regression  0.00548875246448755
# 1504
# length of result  1504
# regression  0.0005468179641950529
# 5439
# length of result  5439
# regression  0.001346099986716491
# 654
# length of result  654
# regression  0.00031126061776290165
# 272
# length of result  272
# regression  0.0004140540801394989
# 905
# length of result  905
# regression  0.0006556498163585092
# 248
# length of result  248
# regression  0.018684674205444302
# 1653
# length of result  1653
# regression  -0.00035888822546623723
# 138
# length of result  138
# regression  -0.0021599417200037505
# 1372
# length of result  1372
# regression  0.008253928183753246
# 212
# length of result  212
# regression  -0.00012557517670959404
# 1872
# length of result  1872
# regression  0.0050404987540305125
# 8815
# length of result  8815
# regression  -0.002227175891996577
# 148
# length of result  148
# regression  -0.005475832483971219
# 130
# length of result  130
# regression  0.0003262434917469811
# 9400
# length of result  9400
# regression  -0.00023999816003993622
# 1599
# length of result  1599
# regression  -0.0027867909249580944
# 878
# length of result  878
# regression  0.0009282680999351512
# 2662
# length of result  2662
# regression  8.875576290387e-05
# 2000
# length of result  2000
# regression  -0.004581470985254727
# 321
# length of result  321
# regression  -0.0001256241759387443
# 3615
# length of result  3615
# regression  0.0023134052351765125
# 5479
# length of result  5479
# regression  -0.0007681833077812719
# 2133
# length of result  2133
# regression  -0.0010964117353936941
# 5704
# length of result  5704
# regression  0.0024740637976480274
# 177
# length of result  177
# regression  0.0022304727938454024
# 1221
# length of result  1221
# regression  0.002111887260094308
# 196
# length of result  196
# regression  0.0016311818728708188
# 149
# length of result  149
# regression  -0.005904739842403184
# 319
# length of result  319
# regression  0.007538498760084653
# 656
# length of result  656
# regression  -0.0008000624764532469
# 302
# length of result  302
# regression  0.006603197098113067
# 1217
# length of result  1217
# regression  0.010245173190362373
# 703
# length of result  703
# regression  0.00011099133155836722
# 2373
# length of result  2373
# regression  -0.004139382410162472
# 604
# length of result  604
# regression  -0.0019353029033296984
# 212
# length of result  212
# regression  6.883627061821026e-05
# 4217
# length of result  4217
# regression  -0.0048885592881901686
# 101
# length of result  101
# regression  0.02211109754393703
# 1165
# length of result  1165
# regression  0.005137764046939732
# 1918
# length of result  1918
# regression  -0.00658017114583683
# 2315
# length of result  2315
# regression  -0.0005722333045265688
# 1746
# length of result  1746
# regression  0.004319163392531759
# 2593
# length of result  2593
# regression  0.0011144216317589238
# 2342
# length of result  2342
# regression  0.007181473542906584
# 110
# length of result  110
# regression  0.0005608461428135914
# 292
# length of result  292
# regression  0.0007067944169690321
# 560
# length of result  560
# regression  0.0013264647954557521
# 1472
# length of result  1472
# regression  0.005489333587782627
# 1948
# length of result  1948
# regression  -0.004740376754930914
# 538
# length of result  538
# regression  0.007151555260866375
# 4001
# length of result  4001
# regression  -0.002264061098918462
# 2149
# length of result  2149
# regression  -0.00040751296493118905
# 4001
# length of result  4001
# regression  0.004347305625983491
# 809
# length of result  809
# regression  -0.0028063343789942767
# 2001
# length of result  2001
# regression  0.0049572826827776586
# 523
# length of result  523
# regression  0.003703376207533254
# 120
# length of result  120
# regression  0.0013021783196811565
# 395
# length of result  395
# regression  0.0016136374335955052
# 2439
# length of result  2439
# regression  0.002297578095328969
# 106
# length of result  106
# regression  -0.004497659668753116
# 2791
# length of result  2791
# regression  0.001297767536761959
# 1390
# length of result  1390
# regression  0.0008351133284498472
# 195
# length of result  195
# regression  0.001995174282117883
# 167
# length of result  167
# regression  -0.004847278674065634
# 131
# length of result  131
# regression  -0.0020382161576912973
# 118
# length of result  118
# regression  0.007731945473485328
# 133
# length of result  133
# regression  0.004843195741473746
# 2004
# length of result  2004
# regression  0.00838996362761809
# 126
# length of result  126
# regression  0.0019057134034716253
# 344
# length of result  344
# regression  0.0017784943711129935
# 1806
# length of result  1806
# regression  0.0005292692378047274
# 148
# length of result  148
# regression  -0.003267595757735123
# 467
# length of result  467
# regression  0.0005656776730789782
# 164
# length of result  164
# regression  0.00020435170769631553
# 1162
# length of result  1162
# regression  -0.002351209835910342
# 103
# length of result  103
# regression  0.00036975881213117387
# 339
# length of result  339
# regression  -0.002227669695438572
# 189
# length of result  189
# regression  0.008364726744191787
